# %%
import tensorflow as tf
import numpy as np
import os
import pickle
from sklearn.model_selection import train_test_split
import librosa

# unpack the pickle
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_dir = '/content/drive/MyDrive/FALL_2022_SEMESTER/COMS_4995_Applied_Deep_Learning/Course_Project/music_dataset/'
pickle_file_path = os.path.join(dataset_dir, 'data_waug.pickle')

# unpack the pickle file
pickle_in = open(pickle_file_path, "rb")
test_data = pickle.load(pickle_in)

# %%
len(test_data)
# Out:
# 1599

# %%
# create mel chroma pickle
spec_cent_dataset = []
for index, val in enumerate(test_data):
  x = (val[0]).astype(float)
  #print(x)
  spec_cent = librosa.feature.chroma_stft(y=x, sr=22050)
  spec_cent_dataset.append((spec_cent, val[1]))

  if index % 100 == 0:
    print(index)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500

# %%
file_path = os.path.join(dataset_dir, 'mel_chroma_pic_waug.pickle')
pickle_out = open(file_path, 'wb')
pickle.dump(spec_cent_dataset, pickle_out)
pickle_out.close()

# %%
# create spectral centroid pickle
spec_cent_dataset = []
for index, val in enumerate(test_data):
  x = (val[0]).astype(float)
  #print(x)
  spec_cent = librosa.feature.spectral_centroid(y=x, sr=22050)
  spec_cent_dataset.append((spec_cent, val[1]))

  if index % 100 == 0:
    print(index)
# Out:
# 22050

# %%
# create spectral bandwidth pickle
spec_cent_dataset = []
for index, val in enumerate(test_data):
  x = (val[0]).astype(float)
  #print(x)
  spec_cent = librosa.feature.spectral_bandwidth(y=x, sr=22050)
  spec_cent_dataset.append((spec_cent, val[1]))

  if index % 100 == 0:
    print(index)

# %%
# create mel SCC pickle
spec_cent_dataset = []
for index, val in enumerate(test_data):
  x = (val[0]).astype(float)
  #print(x)
  spec_cent = librosa.feature.mfcc(y=x, sr=22050)
  spec_cent_dataset.append((spec_cent, val[1]))

  if index % 100 == 0:
    print(index)
